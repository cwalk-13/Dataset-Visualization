# %% [markdown]
# # Video Game Sales
# Dataset source: https://www.kaggle.com/gregorut/videogamesales
# Note: a copy of this dataset is already included in `input_data/vgsales.csv`
#
# ## TODO: your EDA story here

# %% [markdown]
# ## Bar Charts

# %%
import importlib
import mypytable
import utils
import plot_utils
import os
importlib.reload(mypytable)
importlib.reload(utils)
importlib.reload(plot_utils)

vg_file = os.path.join("input_data", "vgsales.csv")
vg_mypy = utils.load_data(vg_file)

plot_utils.bar_chart(vg_mypy, "Platform")
plot_utils.bar_chart(vg_mypy, "Year")
plot_utils.bar_chart(vg_mypy, "Genre")

# %% [markdown]
# ## Pie Chart:

# %%
importlib.reload(mypytable)
importlib.reload(utils)
importlib.reload(plot_utils)
